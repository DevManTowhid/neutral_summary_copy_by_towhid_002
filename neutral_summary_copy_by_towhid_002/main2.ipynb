# %%
# !python model_script.py --mode lm --epochs 1 --batch_size 128 --lr 0.0001 --model-name sentiment_agnostic_model_trial
# Out:
# Vocabulary size: 5005
# ✅ Loading GloVe embeddings from D:/Desktop/neutral_summary_copy_by_towhid_002/neutral_summary_copy_by_towhid/glove.6B\glove.6B.200d.txt
# Training Language Model for 1 epochs...
# | Epoch: 001 | Train loss: 0.695 | Valid loss: 0.692 | time: 4.51s'
# Saved model in ./outputs/models/lm/sentiment_agnostic_model_trial.
# 2025-10-18 11:04:58.696060: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-10-18 11:05:06.377929: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
#
# ...
